# %% [markdown]
# # Basic checklist :
#
# ## I) Sampling :
#
# ###   1) UnderSampling :
# ####       * Description of UnderSampling technique (See Readme)
# ####       * Implementation .
# ####
# ###    2) OverSampling :
# ####       * Description of OverSampling technique. (See Readme)
# ####       * Implementation and code snippet.
# ####
# ###    3) Conclusion :
# ####       * Summary of the sampling techniques and their impact on model performance. (See Readme)
#
# ## II) Multi-Model Approach:
#
# ###    1) Decision Tree Classifier
# ####       * Description of the Decision Tree Classifier algorithm. (See Readme)
# ####       * Implementation .
# ####       * Evaluation of the Decision Tree Classifier.
# ###    2) Random Forest Classifier
# ####       *Description of the Random Forest Classifier algorithm. (See Readme)
# ####       *Implementation .
# ####       *Evaluation of the Random Forest Classifier.
# ###    3) Gradient Boosting Classifier
# ####       * Description of the Gradient Boosting Classifier algorithm. (See Readme)
# ####       * Implementation .
# ####       * Evaluation of the Gradient Boosting Classifier.
# ###    4) Support Vector Classifier (SVC)
# ####       * Description of the Support Vector Classifier algorithm. (See Readme)
# ####       * Implementation .
# ####       * Evaluation of the Support Vector Classifier.
#
# ## III) Model Comparison:
#
# ###    1) Visual comparison of model performance metrics.
# ###    2) Final recommendation for model selection.

# %%
            # import libraries : 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tools import *
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from sklearn.tree import DecisionTreeClassifier
import warnings
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, cross_validate, validation_curve
from sklearn.impute import KNNImputer
import numpy as np
from sklearn.svm import SVC 
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.svm import SVC
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
warnings.simplefilter(action='ignore', category=Warning)

# %%
current_dir = os.getcwd()

parent_dir = os.path.dirname(current_dir)
parent_dir
string=parent_dir+'//features_engineerd//Comfort_Score.csv'

df=pd.read_csv(string)

X = df.drop('Comfort_score', axis = 1)
y = df['Comfort_score']
scaled=StandardScaler()
X_scaled=scaled.fit_transform(X.to_numpy())
df.head()
# Out:
#    Digital Engagement Score  Use of Technology  Fraud Detection Efficiency  Comfort_score
# 0                     55.93                  1                   57.041930              2
# 1                     73.44                  0                   22.888096              1
# 2                     55.74                  1                   81.877149              2
# 3                     58.18                  2                   80.788540              3
# 4                     80.15                  2                   90.494910              3

# %%
show_cluster_distrid(df,'Comfort_score')

# %% [markdown]
# # I) Sampling

# %% [markdown]
# ##

# %% [markdown]
# ## 1) Undersampling

# %%
print(Counter(y))

undersample = RandomUnderSampler()
undersampled_X, undersampled_y = undersample.fit_resample(X_scaled, y.to_numpy())
print(Counter(undersampled_y))

undersampled_X=pd.DataFrame(undersampled_X,columns=df.drop('Comfort_score', axis = 1).columns)
undersampled_y=pd.DataFrame(undersampled_y,columns=['Comfort_score'])
# Out:
# Counter({0: 2554, 3: 2545, 1: 2498, 2: 2403})
# Counter({0: 2403, 1: 2403, 2: 2403, 3: 2403})

# %% [markdown]
# ## 2) OverSampling

# %%
Knn_nighbert_params(X_scaled,y,12)

# %%
smote = SMOTE(sampling_strategy='auto',k_neighbors=1)
print(Counter(y))

oversampling_X, oversampling_y = smote.fit_resample(X,y)

print(Counter(oversampling_y))
oversampling_X=pd.DataFrame(oversampling_X,columns=df.drop('Comfort_score', axis = 1).columns)
oversampling_y=pd.DataFrame(oversampling_y,columns=['Comfort_score'])
# Out:
# Counter({0: 2554, 3: 2545, 1: 2498, 2: 2403})
# Counter({2: 2554, 1: 2554, 3: 2554, 0: 2554})

# %% [markdown]
# ## 3) Conclusion

# %% [markdown]
# * the distribution of the target classes is relatively balanced, undersampling using RandomUnderSampler might be a safer choice to avoid potential overfitting that could occur with SMOTE .

# %%
liste_models_metrics=dict()

# %%
X_sampled,y_sampled=oversampling_X,oversampling_y

# %% [markdown]
# ## II) Multi-Model Approach:

# %% [markdown]
# ### 1) Decision Tree Classifier

# %%
random_grid  = {
    'criterion': ['gini', 'entropy'],
    'max_depth': range(2, 51),
    'min_samples_split': range(2, 11),
    'min_samples_leaf': range(1, 11),
    'max_features': ['sqrt', 'log2', None]
}

print(random_grid)
best_params=modeling(DecisionTreeClassifier,X_sampled,y_sampled,random_grid)
# Out:
# {'criterion': ['gini', 'entropy'], 'max_depth': range(2, 51), 'min_samples_split': range(2, 11), 'min_samples_leaf': range(1, 11), 'max_features': ['sqrt', 'log2', None]}
# {'Accuracy': 0.9951060358890701, 'F1 Score': 0.99510538242175, 'Precision': 0.9951163358660406, 'Recall': 0.9951060358890701, 'confusion_matrix': array([[794,   1,   1,   0],
#        [  1, 747,   0,   0],
#        [  1,   0, 787,   4],
#        [  0,   6,   1, 722]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': 31, 'criterion': 'entropy'}
# {'Accuracy': 0.9964110929853182, 'F1 Score': 0.9964103573253025, 'Precision': 0.9964172694043594, 'Recall': 0.9964110929853182, 'confusion_matrix': array([[795,   0,   1,   0],
#        [  1, 747,   0,   0],
#        [  2,   0, 788,   2],
#        [  1,   4,   0, 724]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
best_model=DecisionTreeClassifier(**best_params)
best_model.fit(X_train,y_train)
y_pred=best_model.predict(X_test)
y_proba=best_model.predict_proba(X_test)
print(get_metrics(y_pred,y_test))
ROC_multi_class(best_model,y_pred,y_proba,X_test,y_test,'Comfort_score')
# Out:
# {'Accuracy': 0.9960848287112561, 'F1 Score': 0.9960848850180416, 'Precision': 0.9960857901257174, 'Recall': 0.9960848287112561, 'confusion_matrix': array([[760,   1,   1,   0],
#        [  0, 763,   1,   2],
#        [  2,   0, 793,   2],
#        [  1,   1,   1, 737]], dtype=int64)}

# %%
# Add the Best Decisiontree model into a Model_list for the Final comparison
metric_dic=get_metrics(y_pred,y_test)
metric_dic.pop('confusion_matrix')
print(metric_dic)
if 'DecisionTree' not in liste_models_metrics.keys():
    liste_models_metrics['DecisionTree']=metric_dic
# Out:
# {'Accuracy': 0.9960848287112561, 'F1 Score': 0.9960848850180416, 'Precision': 0.9960857901257174, 'Recall': 0.9960848287112561}

# %% [markdown]
# .
#
#
#
#
# .

# %% [markdown]
# ### 2) Random Forest Classifier

# %%
 
random_grid = {'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
               'max_features': ['auto', 'sqrt','log2'],
               'max_depth': [int(x) for x in np.linspace(10, 1000,10)],
               'min_samples_split': [2, 5, 10,14],
               'min_samples_leaf': [1, 2, 4,6,8],
              'criterion':['entropy','gini']}
print(random_grid)
best_params=modeling(RandomForestClassifier,X_sampled,y_sampled,random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}
# {'Accuracy': 0.9954323001631321, 'F1 Score': 0.9954331148475261, 'Precision': 0.9954352058842311, 'Recall': 0.9954323001631321, 'confusion_matrix': array([[755,   0,   1,   0],
#        [  0, 755,   1,   3],
#        [  1,   0, 779,   3],
#        [  0,   2,   3, 762]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'n_estimators': 1400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 120, 'criterion': 'entropy'}
# {'Accuracy': 0.9970636215334421, 'F1 Score': 0.9970646451000957, 'Precision': 0.9970677838199706, 'Recall': 0.9970636215334421, 'confusion_matrix': array([[755,   0,   1,   0],
#        [  0, 756,   1,   2],
#        [  0,   0, 781,   2],
#        [  0,   1,   2, 764]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
RandomForest_model=RandomForestClassifier(**{'n_estimators': 1400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 120, 'criterion': 'entropy'})
RandomForest_model.fit(X_train,y_train)
y_pred=RandomForest_model.predict(X_test)
y_proba=RandomForest_model.predict_proba(X_test)
ROC_multi_class(RandomForest_model,y_pred,y_proba,X_test,y_test,'Comfort_score')

# %%
metric_dic=get_metrics(y_pred,y_test)
metric_dic.pop('confusion_matrix')
print(metric_dic)
if 'RandomForestClassifier' not in liste_models_metrics.keys():
    liste_models_metrics['RandomForestClassifier']=metric_dic
# Out:
# {'Accuracy': 0.9967373572593801, 'F1 Score': 0.9967390981297927, 'Precision': 0.9967463080825457, 'Recall': 0.9967373572593801}

# %% [markdown]
# ###    3) Gradient Boosting Classifier:

# %%
random_grid = {
    'n_estimators': np.arange(50, 251, 50),
    'learning_rate': np.linspace(0.01, 0.2, 10),
    'max_depth': np.arange(3, 8),
}
best_params=modeling(GradientBoostingClassifier,X_sampled,y_sampled,random_grid)
# Out:
# {'Accuracy': 0.9938009787928221, 'F1 Score': 0.9937953957288034, 'Precision': 0.9938080566759051, 'Recall': 0.9938009787928221, 'confusion_matrix': array([[784,   0,   1,   0],
#        [  0, 749,   0,   1],
#        [  4,   1, 758,   4],
#        [  1,   5,   2, 755]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.09444444444444444}
# {'Accuracy': 0.9941272430668842, 'F1 Score': 0.9941220709989286, 'Precision': 0.9941304481294156, 'Recall': 0.9941272430668842, 'confusion_matrix': array([[784,   0,   1,   0],
#        [  0, 749,   1,   0],
#        [  4,   0, 759,   4],
#        [  1,   5,   2, 755]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
best_model=GradientBoostingClassifier(**best_params)
best_model.fit(X_train,y_train)
y_pred=best_model.predict(X_test)
y_proba=best_model.predict_proba(X_test)
ROC_multi_class(best_model,y_pred,y_proba,X_test,y_test,'Comfort_score')

# %%
metric_dic=get_metrics(y_pred,y_test)
metric_dic.pop('confusion_matrix')
if 'GradientBoostingClassifier' not in liste_models_metrics.keys():
    liste_models_metrics['GradientBoostingClassifier']=metric_dic

# %% [markdown]
# ### 4) Support Vector Classifier (SVC)

# %%
random_grid = {'C': [0.1, 1, 10, 100], 'gamma': [0.01, 0.1, 1, 10],'kernel':['rbf']}

best_params=modeling(SVC,X_sampled,y_sampled,random_grid,proba=False)
# Out:
# {'Accuracy': 0.9432300163132137, 'F1 Score': 0.9432269870723721, 'Precision': 0.9432692988999685, 'Recall': 0.9432300163132137, 'confusion_matrix': array([[705,  16,  22,   2],
#        [ 20, 729,   0,  18],
#        [ 24,   0, 730,  22],
#        [  3,  30,  17, 727]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'kernel': 'rbf', 'gamma': 0.1, 'C': 100}
# {'Accuracy': 0.9814029363784665, 'F1 Score': 0.981398813986124, 'Precision': 0.9814316856089623, 'Recall': 0.9814029363784665, 'confusion_matrix': array([[729,   7,   9,   0],
#        [  5, 757,   0,   5],
#        [  6,   0, 765,   5],
#        [  3,  10,   7, 757]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
best_model=SVC(**best_params)
best_model.fit(X_train,y_train)
y_pred=best_model.predict(X_test)
#ROC_multi_class(best_model,y_pred,y_proba,X_test,y_test,'Financial_solidity')

# %%
metric_dic=get_metrics(y_pred,y_test)
metric_dic.pop('confusion_matrix')
if 'SVM' not in liste_models_metrics.keys():
    liste_models_metrics['SVM']=metric_dic

# %% [markdown]
# # III) Model Comparison:

# %%
model_comparasion(list(liste_models_metrics.values()),list(liste_models_metrics.keys()),'Comfort_score')
# Out:
# Accuracy : dict_values([0.9960848287112561, 0.9960848850180416, 0.9960857901257174, 0.9960848287112561])
# F1 Score : dict_values([0.9964110929853182, 0.9964112326982376, 0.9964169249326311, 0.9964110929853182])
# Precision : dict_values([0.9947797716150082, 0.994779947885414, 0.9947954447159916, 0.9947797716150082])
# Recall : dict_values([0.9814029363784665, 0.9814220382892405, 0.981619939638952, 0.9814029363784665])

# %% [markdown]
# ## Conclusion:
#
# * Upon comprehensive evaluation and comparison of all models utilized, Random Forest emerges as the top performer across all evaluation metrics, including precision, recall, F1-score, and ROC-AUC. Its superior performance is consistently observed across various aspects of model evaluation, affirming its robustness and effectiveness in handling the classification task. Furthermore, Random Forest demonstrates a notably favorable learning curve, depicting steady improvement with increasing training data size and indicating its ability to generalize well to unseen data. Hence, considering its exceptional performance and reliable learning behavior, Random Forest stands out as the optimal choice for the classification task under consideration.

# %% [markdown]
# # Save Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
RandomForest_model=RandomForestClassifier(**{'n_estimators': 1400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 120, 'criterion': 'entropy'})
RandomForest_model.fit(X_train.to_numpy(),y_train.to_numpy())
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=120, n_estimators=1400)

# %%
# Create new folder

directory = "Comfort_Classification_models"
  
# Parent Directory path 
  
# Path 
models_directory=parent_dir+'\models'
path = os.path.join(models_directory, directory) 
try:
    os.mkdir(path)
except Exception as e:
    print(e.args[1])
    pass
print(path)
# Out:
# C:\Users\Haboubi\PFE2\classification\models\Comfort_Classification_models

# %%
# Save Model
import joblib
joblib.dump(RandomForest_model, path+'\Comfort_Classification_model.joblib')
# Out:
# ['C:\\Users\\Haboubi\\PFE2\\classification\\models\\Comfort_Classification_models\\Comfort_Classification_model.joblib']

# %%
# Save Features
df.dtypes.to_pickle(path+'\Comfort_Classification_Features.pkl')

# %%
# save Scaler
joblib.dump(scaled, path+'\Comfort_Classification_scaler.joblib')
# Out:
# ['C:\\Users\\Haboubi\\PFE2\\classification\\models\\Comfort_Classification_models\\Comfort_Classification_scaler.joblib']

# %% [markdown]
# ## Add model/scaler into the table models in Postgres sql

# %%
import psycopg2
import pickle
db_config = {
    'dbname': 'postgres',
    'user': 'admin',
    'password': 'admin',
    'host': 'localhost',  
    'port': '5432'  
}



model_name="Comfort_Classification_model"
scaler_name="Comfort_Classification_scaler"
model_blob = pickle.dumps(RandomForest_model)
scaled_blob=pickle.dumps(scaled)

# %%
try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_config)
    cursor = conn.cursor()

   
    # Insert the model into the table
    insert_model_query = """
    INSERT INTO model_storage (model_name, model_data)
    VALUES (%s, %s);
    """
    cursor.execute(insert_model_query, (model_name, model_blob))
    conn.commit()

    # Insert the scaler into the table
    insert_scaler_query = """
    INSERT INTO scalers_storage (scaled_name, scaled_data)
    VALUES (%s, %s);
    """
    cursor.execute(insert_scaler_query, (scaler_name, scaled_blob))
    conn.commit()
    print("scaler saved to PostgreSQL successfully!")

except Exception as e:
    print(f"An error occurred: {e}")
finally:
    # Close the cursor and connection
    if cursor:
        cursor.close()
    if conn:
        conn.close()
