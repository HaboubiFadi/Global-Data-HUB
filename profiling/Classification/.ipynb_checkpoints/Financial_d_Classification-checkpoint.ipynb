# %% [markdown]
# # Basic checklist :
#
# ## I) Sampling :
#
# ###   1) UnderSampling :
# ####       * Description of UnderSampling technique (See Readme)
# ####       * Implementation .
# ####
# ###    2) OverSampling :
# ####       * Description of OverSampling technique. (See Readme)
# ####       * Implementation and code snippet.
# ####
# ###    3) Conclusion :
# ####       * Summary of the sampling techniques and their impact on model performance. (See Readme)
#
# ## II) Multi-Model Approach:
#
# ###    1) Decision Tree Classifier
# ####       * Description of the Decision Tree Classifier algorithm. (See Readme)
# ####       * Implementation .
# ####       * Evaluation of the Decision Tree Classifier.
# ###    2) Random Forest Classifier
# ####       *Description of the Random Forest Classifier algorithm. (See Readme)
# ####       *Implementation .
# ####       *Evaluation of the Random Forest Classifier.
# ###    3) Gradient Boosting Classifier
# ####       * Description of the Gradient Boosting Classifier algorithm. (See Readme)
# ####       * Implementation .
# ####       * Evaluation of the Gradient Boosting Classifier.
# ###    4) Support Vector Classifier (SVC)
# ####       * Description of the Support Vector Classifier algorithm. (See Readme)
# ####       * Implementation .
# ####       * Evaluation of the Support Vector Classifier.
#
# ## III) Model Comparison:
#
# ###    1) Visual comparison of model performance metrics.
# ###    2) Final recommendation for model selection.

# %%
# import libraries : 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tools import *
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from sklearn.tree import DecisionTreeClassifier
import warnings
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, cross_validate, validation_curve
from sklearn.impute import KNNImputer
import numpy as np
from sklearn.svm import SVC 
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.svm import SVC
import os
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
warnings.simplefilter(action='ignore', category=Warning)

# %%
current_dir = os.getcwd()

parent_dir = os.path.dirname(current_dir)
parent_dir
string=parent_dir+'//features_engineerd//F_dynamics.csv'

df=pd.read_csv(string)

X = df.drop('Financial_dynamics', axis = 1)
y = df['Financial_dynamics']
scaled=StandardScaler()
X_scaled=scaled.fit_transform(X.to_numpy())
df.head()
# Out:
#    Types of Risk Accepted  Profitability  Market Penetration  ESG Score  Revenue Growth Rate  Annual Revenue  Financial_dynamics
# 0                       0           0.30                6.48       2.47            12.915856      5237609.72                   0
# 1                       0           0.45               95.61       1.50            31.561627      2927741.24                   0
# 2                       1           0.36               35.53       1.51            89.980102      4765583.18                   0
# 3                       0           0.33               92.94       1.12            11.612488      1907349.00                   0
# 4                       0           0.46               29.61       1.24             6.073955      2522869.44                   0

# %%
show_cluster_distrid(df,'Financial_dynamics')

# %% [markdown]
# # I) Sampling

# %% [markdown]
# ## 1) Undersampling

# %%
print(Counter(y))

undersample = RandomUnderSampler()
undersampled_X, undersampled_y = undersample.fit_resample(X_scaled, y.to_numpy())
print(Counter(undersampled_y))

undersampled_X=pd.DataFrame(undersampled_X,columns=df.drop('Financial_dynamics', axis = 1).columns)
undersampled_y=pd.DataFrame(undersampled_y,columns=['Financial_dynamics'])
# Out:
# Counter({1: 3651, 0: 3175, 2: 3174})
# Counter({0: 3174, 1: 3174, 2: 3174})

# %% [markdown]
# ## 2) OverSampling

# %%
Knn_nighbert_params(X_scaled,y,12)

# %%
smote = SMOTE(sampling_strategy='auto',k_neighbors=1)
print(Counter(y))

oversampling_X, oversampling_y = smote.fit_resample(X,y)

print(Counter(oversampling_y))
oversampling_X=pd.DataFrame(oversampling_X,columns=df.drop('Financial_dynamics', axis = 1).columns)
oversampling_y=pd.DataFrame(oversampling_y,columns=['Financial_dynamics'])
# Out:
# Counter({1: 3651, 0: 3175, 2: 3174})
# Counter({0: 3651, 2: 3651, 1: 3651})

# %% [markdown]
# ## 3) Conclusion

# %% [markdown]
# * the distribution of the target classes is relatively balanced, undersampling using RandomUnderSampler might be a safer choice to avoid potential overfitting that could occur with SMOTE .

# %%
liste_models_metrics=dict()

# %%
X_sampled,y_sampled=undersampled_X,undersampled_y

# %% [markdown]
# ## II) Multi-Model Approach:

# %% [markdown]
# ### 1) Decision Tree Classifier

# %%
random_grid  = {
    'criterion': ['gini', 'entropy'],
    'max_depth': range(2, 51),
    'min_samples_split': range(2, 11),
    'min_samples_leaf': range(1, 11),
    'max_features': ['sqrt', 'log2', None]
}

print(random_grid)
best_params=modeling(DecisionTreeClassifier,X_sampled,y_sampled,random_grid)
# Out:
# {'criterion': ['gini', 'entropy'], 'max_depth': range(2, 51), 'min_samples_split': range(2, 11), 'min_samples_leaf': range(1, 11), 'max_features': ['sqrt', 'log2', None]}
# {'Accuracy': 0.9698984949247462, 'F1 Score': 0.9698949628249137, 'Precision': 0.969895769423474, 'Recall': 0.9698984949247462, 'confusion_matrix': array([[894,  22,  11],
#        [ 18, 934,  13],
#        [ 11,  11, 943]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 42, 'criterion': 'gini'}
# {'Accuracy': 0.9656982849142457, 'F1 Score': 0.9657266039770183, 'Precision': 0.965810734429777, 'Recall': 0.9656982849142457, 'confusion_matrix': array([[895,  24,   8],
#        [ 22, 932,  11],
#        [ 20,  13, 932]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
best_model=DecisionTreeClassifier(**best_params)
best_model.fit(X_train,y_train)
y_pred=best_model.predict(X_test)
y_proba=best_model.predict_proba(X_test)
print(get_metrics(y_pred,y_test))
ROC_multi_class(best_model,y_pred,y_proba,X_test,y_test,'Financial_dynamics')
# Out:
# {'Accuracy': 0.9702485124256213, 'F1 Score': 0.9702571940039437, 'Precision': 0.9702928840751625, 'Recall': 0.9702485124256213, 'confusion_matrix': array([[934,  22,  12],
#        [ 19, 927,   7],
#        [ 11,  14, 911]], dtype=int64)}

# %%
# Add the Best Decisiontree model into a Model_list for the Final comparison
metric_dic=get_metrics(y_pred,y_test)
metric_dic.pop('confusion_matrix')
print(metric_dic)
if 'DecisionTree' not in liste_models_metrics.keys():
    liste_models_metrics['DecisionTree']=metric_dic
# Out:
# {'Accuracy': 0.9702485124256213, 'F1 Score': 0.9702571940039437, 'Precision': 0.9702928840751625, 'Recall': 0.9702485124256213}

# %% [markdown]
# .
#
#
#
#
# .

# %% [markdown]
# ### 2) Random Forest Classifier

# %%
 
random_grid = {'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
               'max_features': ['auto', 'sqrt','log2'],
               'max_depth': [int(x) for x in np.linspace(10, 1000,10)],
               'min_samples_split': [2, 5, 10,14],
               'min_samples_leaf': [1, 2, 4,6,8],
              'criterion':['entropy','gini']}
print(random_grid)
best_params=modeling(RandomForestClassifier,X_sampled,y_sampled,random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}
# {'Accuracy': 0.9824991249562478, 'F1 Score': 0.9825002065406682, 'Precision': 0.982516784345439, 'Recall': 0.9824991249562478, 'confusion_matrix': array([[931,  10,   9],
#        [  7, 934,  11],
#        [ 11,   2, 942]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'n_estimators': 600, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 120, 'criterion': 'entropy'}
# {'Accuracy': 0.9817990899544977, 'F1 Score': 0.9818026389747359, 'Precision': 0.9818498452375682, 'Recall': 0.9817990899544977, 'confusion_matrix': array([[931,   8,  11],
#        [  9, 931,  12],
#        [ 10,   2, 943]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
best_model=RandomForestClassifier(**best_params)
best_model.fit(X_train,y_train)
y_pred=best_model.predict(X_test)
y_proba=best_model.predict_proba(X_test)
ROC_multi_class(best_model,y_pred,y_proba,X_test,y_test,'Financial_dynamics')

# %%
metric_dic=get_metrics(y_pred,y_test)
metric_dic.pop('confusion_matrix')
print(metric_dic)
if 'RandomForestClassifier' not in liste_models_metrics.keys():
    liste_models_metrics['RandomForestClassifier']=metric_dic
# Out:
# {'Accuracy': 0.9891494574728736, 'F1 Score': 0.9891465398627398, 'Precision': 0.9891538280657688, 'Recall': 0.9891494574728736}

# %% [markdown]
# ###    3) Gradient Boosting Classifier:

# %%
random_grid = {
    'n_estimators': np.arange(50, 251, 50),
    'learning_rate': np.linspace(0.01, 0.2, 10),
    'max_depth': np.arange(3, 8),
}
best_params=modeling(GradientBoostingClassifier,X_sampled,y_sampled,random_grid)
# Out:
# {'Accuracy': 0.9831991599579979, 'F1 Score': 0.983200192386925, 'Precision': 0.9832198887875565, 'Recall': 0.9831991599579979, 'confusion_matrix': array([[926,   9,  10],
#        [  7, 934,  10],
#        [ 10,   2, 949]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.1788888888888889}
# {'Accuracy': 0.9849492474623731, 'F1 Score': 0.9849512995692197, 'Precision': 0.9849591276418902, 'Recall': 0.9849492474623731, 'confusion_matrix': array([[929,   7,   9],
#        [  6, 937,   8],
#        [ 10,   3, 948]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
best_model=GradientBoostingClassifier(**best_params)
best_model.fit(X_train,y_train)
y_pred=best_model.predict(X_test)
y_proba=best_model.predict_proba(X_test)
ROC_multi_class(best_model,y_pred,y_proba,X_test,y_test,'Financial_dynamics')

# %%
metric_dic=get_metrics(y_pred,y_test)
metric_dic.pop('confusion_matrix')
if 'GradientBoostingClassifier' not in liste_models_metrics.keys():
    liste_models_metrics['GradientBoostingClassifier']=metric_dic

# %% [markdown]
# ### 4) Support Vector Classifier (SVC)

# %%
random_grid = {'C': [0.1, 1, 10, 100], 'gamma': [0.01, 0.1, 1, 10],'kernel':['rbf']}

best_params=modeling(SVC,X_sampled,y_sampled,random_grid,proba=False)
# Out:
# {'Accuracy': 0.9849492474623731, 'F1 Score': 0.9849462756461604, 'Precision': 0.9849576094588187, 'Recall': 0.9849492474623731, 'confusion_matrix': array([[948,   9,   8],
#        [ 13, 917,   5],
#        [  6,   2, 949]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
#
#
#
#
# *****************  Random  **************************
#
# Best Params=  {'kernel': 'rbf', 'gamma': 0.01, 'C': 100}
# {'Accuracy': 0.9936996849842492, 'F1 Score': 0.9937001759683354, 'Precision': 0.993701774634451, 'Recall': 0.9936996849842492, 'confusion_matrix': array([[958,   3,   4],
#        [  4, 929,   2],
#        [  4,   1, 952]], dtype=int64)}
#                     /*************************************\
#                     /*************************************\
#                     /*************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
SVC_model=SVC(**{'kernel': 'rbf', 'gamma': 0.01, 'C': 100})
SVC_model.fit(X_train,y_train)
y_pred=SVC_model.predict(X_test)
#ROC_multi_class(best_model,y_pred,y_proba,X_test,y_test,'Financial_solidity')

# %%
metric_dic=get_metrics(y_pred,y_test)
print(metric_dic)
metric_dic.pop('confusion_matrix')
if 'SVM' not in liste_models_metrics.keys():
    liste_models_metrics['SVM']=metric_dic
# Out:
# {'Accuracy': 0.992299614980749, 'F1 Score': 0.9922956498540408, 'Precision': 0.9923396187473057, 'Recall': 0.992299614980749, 'confusion_matrix': array([[915,   1,   4],
#        [  8, 963,   7],
#        [  1,   1, 957]], dtype=int64)}

# %% [markdown]
# # III) Model Comparison:

# %%
plt.figure(figsize=(30,15))
model_comparasion(list(liste_models_metrics.values()),list(liste_models_metrics.keys()),'Financial_dynamics')
# Out:
# Accuracy : dict_values([0.9702485124256213, 0.9702571940039437, 0.9702928840751625, 0.9702485124256213])
# F1 Score : dict_values([0.9891494574728736, 0.9891465398627398, 0.9891538280657688, 0.9891494574728736])
# Precision : dict_values([0.9891494574728736, 0.989151762227994, 0.9891615406480291, 0.9891494574728736])
# Recall : dict_values([0.9908995449772489, 0.9909007090762084, 0.9909029380405223, 0.9908995449772489])

# %% [markdown]
# ## Conclusion:
#
# * Based on the comprehensive evaluation of multiple classification models, including Decision Trees, Random Forests, Gradient Boosting, and Support Vector Machines (SVM), it is evident that SVM emerges as the top-performing model across all evaluated metrics, including Accuracy, F1 Score, Precision, and Recall. SVM's superior performance can be attributed to its ability to effectively handle nonlinear relationships, robustness to outliers, balanced trade-off between bias and variance, effectiveness in high-dimensional feature spaces, and tunability of hyperparameters. By leveraging these strengths, SVM demonstrates robust and consistent performance across various datasets and can be considered a reliable choice for classification tasks. Therefore, based on the observed results and analysis, SVM stands out as the preferred model for the classification problem at hand, offering optimal performance and predictive accuracy.

# %% [markdown]
# # Save Model

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled, test_size=0.3)
SVC_model=SVC(**{'kernel': 'rbf', 'gamma': 0.01, 'C': 100})
SVC_model.fit(X_train.to_numpy(),y_train.to_numpy())
# Out:
# SVC(C=100, gamma=0.01)

# %%
# Create new folder

directory = "Financial_d_Classification_models"
  
# Parent Directory path 
  
# Path 
models_directory=parent_dir+'\models'
path = os.path.join(models_directory, directory) 
try:
    os.mkdir(path)
except Exception as e:
    print(e.args[1])
    pass
print(path)
# Out:
# Impossible de créer un fichier déjà existant
# C:\Users\Haboubi\PFE2\classification\models\Financial_d_Classification_models

# %%
# Save Model
import joblib
joblib.dump(SVC_model, path+'\Financial_d_Classification_model.joblib')
# Out:
# ['C:\\Users\\Haboubi\\PFE2\\classification\\models\\Financial_d_Classification_models\\Financial_d_Classification_model.joblib']

# %%
# Save Features
df.dtypes.to_pickle(path+'\Financial_d_Classification_Features.pkl')

# %%
# save Scaler
joblib.dump(scaled, path+'\Financial_d_Classification_scaler.joblib')
# Out:
# ['C:\\Users\\Haboubi\\PFE2\\classification\\models\\Financial_d_Classification_models\\Financial_d_Classification_scaler.joblib']

# %% [markdown]
# ## Add model/scaler into the table models in Postgres sql

# %%
import psycopg2
import pickle
db_config = {
    'dbname': 'postgres',
    'user': 'admin',
    'password': 'admin',
    'host': 'localhost',  
    'port': '5432'  
}



model_name="Financial_d_Classification_model"
scaler_name="Financial_d_Classification_scaler"
model_blob = pickle.dumps(SVC_model)
scaled_blob=pickle.dumps(scaled)

# %%
try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_config)
    cursor = conn.cursor()

   
    # Insert the model into the table
    insert_model_query = """
    INSERT INTO model_storage (model_name, model_data)
    VALUES (%s, %s);
    """
    cursor.execute(insert_model_query, (model_name, model_blob))
    conn.commit()

    # Insert the scaler into the table
    insert_scaler_query = """
    INSERT INTO scalers_storage (scaled_name, scaled_data)
    VALUES (%s, %s);
    """
    cursor.execute(insert_scaler_query, (scaler_name, scaled_blob))
    conn.commit()
    print("scaler saved to PostgreSQL successfully!")

except Exception as e:
    print(f"An error occurred: {e}")
finally:
    # Close the cursor and connection
    if cursor:
        cursor.close()
    if conn:
        conn.close()
